# %% [markdown]
# # Data Analytics on House Price dataset

# %% [markdown]
# ### We are going to perform analytics on house price dataset. There we have multiple attributes who can help us to decide price of the house

# %% [markdown]
# ### Import the required libraries

# %%
# Import the numerical Python 
# Numpy is used for performing numerical operations on the different data structures 
import numpy as np

# Import the pandas library
# Pandas is used for converting different data structures into pandas dataframe
import pandas as pd

# Import the seaborn
# Seaborn is used to visualize the data structures
import seaborn as sns

# Import the matplotlib
# Matplotlib is the major library utilized for visualization of any data structure
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load the dataset

# %%
 # Read the dataset from local
df_house_price = pd.read_csv('C://Users//Asus//Downloads//House_Price (3).csv')

# %% [markdown]
# ### Data overview

# %%
# Show the first 5 observation(row) of the data
df_house_price.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98     YES       5.480      11.1920
# 1   5.12   5.06      22.2       9.14      NO       7.332      12.1728
# 2   5.01   4.97      22.2       4.03      NO       7.394     101.1200
# 3   6.16   5.96      21.3       2.94     YES       9.268      11.2672
# 4   6.37   5.86      21.3       5.33      NO       8.824      11.2896
#
#   waterbody  rainfall bus_ter     parks
# 0     River        23     YES  0.049347
# ...

# %%
# Show me the last 5 observation
df_house_price.tail()
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 501   22.4     0.06263       41.93     0.573     6.593  69.1   2.64   2.45
# 502   20.6     0.04527       41.93     0.573     6.120  76.7   2.44   2.11
# 503   23.9     0.06076       41.93     0.573     6.976  91.0   2.34   2.06
# 504   22.0     0.10959       41.93     0.573     6.794  89.3   2.54   2.31
# 505   19.0     0.04741       41.93     0.573     6.030  80.8   2.72   2.24
#
#      dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 501   2.76   2.06      19.0       9.67      NO       9.348      12.1792
# 502   2.46   2.14      19.0       9.08     YES       6.612      13.1648
# 503   2.29   1.98      19.0       5.64      NO       5.478      12.1912
# 504   2.40   2.31      19.0       6.48     YES       7.940      15.1760
# 505   2.64   2.42      19.0       7.88     YES      10.280      10.1520
#
#           waterbody  rainfall bus_ter     parks
# ...

# %% [markdown]
# ### Check the shape of the data

# %%
df_house_price.shape
# Out:
# (506, 19)

# %% [markdown]
# ### Interpretation
# - We have 506 observations(rows) in the data
# - We have 19 attributes(columns)

# %%
# Derive the basic information 
df_house_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        506 non-null    float64
#  1   crime_rate   506 non-null    float64
#  2   resid_area   506 non-null    float64
#  3   air_qual     506 non-null    float64
#  4   room_num     506 non-null    float64
#  5   age          506 non-null    float64
#  6   dist1        506 non-null    float64
#  7   dist2        506 non-null    float64
#  8   dist3        506 non-null    float64
#  9   dist4        506 non-null    float64
#  10  teachers     506 non-null    float64
#  11  poor_prop    506 non-null    float64
#  12  airport      506 non-null    object
#  13  n_hos_beds   498 non-null    float64
#  14  n_hot_rooms  506 non-null    float64
#  15  waterbody    351 non-null    object
#  16  rainfall     506 non-null    int64
#  17  bus_ter      506 non-null    object
# ...

# %% [markdown]
# ### Interpretation
# - In the data, we have 16 numerical columns(float + int)
# - In the data, we have 3 categorical columns(object)
# - Memory usage is 75.2+ KB
# - In the data, we have null values

# %%
# Describe the dataset
df_house_price.describe().T
# Out:
#              count       mean        std        min        25%        50%  \
# price        506.0  22.528854   9.182176   5.000000  17.025000  21.200000
# crime_rate   506.0   3.613524   8.601545   0.006320   0.082045   0.256510
# resid_area   506.0  41.136779   6.860353  30.460000  35.190000  39.690000
# air_qual     506.0   0.554695   0.115878   0.385000   0.449000   0.538000
# room_num     506.0   6.284634   0.702617   3.561000   5.885500   6.208500
# age          506.0  68.574901  28.148861   2.900000  45.025000  77.500000
# dist1        506.0   3.971996   2.108532   1.130000   2.270000   3.385000
# dist2        506.0   3.628775   2.108580   0.920000   1.940000   3.010000
# dist3        506.0   3.960672   2.119797   1.150000   2.232500   3.375000
# dist4        506.0   3.618972   2.099203   0.730000   1.940000   3.070000
# teachers     506.0  21.544466   2.164946  18.000000  19.800000  20.950000
# poor_prop    506.0  12.653063   7.141062   1.730000   6.950000  11.360000
# ...

# %% [markdown]
# ### Interpretation
# - Average price is 22.528854, Minimum price is 5, Maximum price is 50
# - Average  crime_rate is 3.613524, Minimum crime_rate is 0.006320,Maximum crime_rate is 88.976200
# - Average resid_area is 41.136779, Minimum resid_area is 30.46, Maximum resid_area is 57.74
# - Average air_qual is 0.554695, Minimum air_qual is 0.3850, Maximum air_qual is 0.871
# - Average room_num is 6.284634, Minimum room_num is 3.5610, Maximum room_num is 8.780
# - Average age is 68.574901, Minimum age is 2.9, Maximum age is
# - Average dstance 1 is 3.628775, Minimum distance 1 is 1.130000 ,Maximum distance is 12.320000
# - Average distance 2 is 3.628775, Minimum distance 2 is 0.920000, Maximum distance is 11.930000
# - Average distance 3 is 3.960672,Minimum distance 3 is 1.150000,Maximum distance 3 is 12.320000
# - Average distance 4 is 3.618972 ,Minimum distance 4 is 0.730000,Maximum distance 4 is 11.940000
# - Average teachers is 21.544466,Minimum teachers is 18.000000, Maximum teachers is 27.400000
# - Average poor_prop is 12.653063 ,Minimum poor_prop is 1.730000, Maximum poor_prop is 37.970000
# - Average n_hos_beds is 7.899767, Minimum n_hos_beds is 5.268000 , Maximum n_hos_beds is 37.970000
# - Average n_hot_rooms is 13.041605 , Minimum n_hot_rooms is 10.057600,Maximum n_hot_rooms is 101.120000
# - Average rainfall is 39.181818,Minimum rainfall is 3.000000 ,Maximum rainfall is 60.000000
# - Average Parks is 0.054454, minimum parks is 0.033292, Maximum parks is 0.086711

# %% [markdown]
# ### Data Preprocessing

# %% [markdown]
# ### Data Cleaning

# %%
# Show the first 5 observation of the data
df_house_price.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98     YES       5.480      11.1920
# 1   5.12   5.06      22.2       9.14      NO       7.332      12.1728
# 2   5.01   4.97      22.2       4.03      NO       7.394     101.1200
# 3   6.16   5.96      21.3       2.94     YES       9.268      11.2672
# 4   6.37   5.86      21.3       5.33      NO       8.824      11.2896
#
#   waterbody  rainfall bus_ter     parks
# 0     River        23     YES  0.049347
# ...

# %%
# To make the data representable we need to rename the colums
df_house_price.columns
# Out:
# Index(['price', 'crime_rate', 'resid_area', 'air_qual', 'room_num', 'age',
#        'dist1', 'dist2', 'dist3', 'dist4', 'teachers', 'poor_prop', 'airport',
#        'n_hos_beds', 'n_hot_rooms', 'waterbody', 'rainfall', 'bus_ter',
#        'parks'],
#       dtype='object')

# %%
# Dfine the new column names
d1 = {'price': 'Price', 
 'crime_rate': 'Crime_Rate',
 'resid_area': 'Residential_Area',
 'air_qual': 'Air_Quality',
 'room_num': 'Room_Numbers',
 'age': 'Age_of_the_House',
 'distance': 'Distance_From_Industries',
 'teachers': 'Number_of_Teachers',
 'poor_prop': 'Proportion_of_Poor_Population',
 'airport': 'Airport',
 'n_hos_beds': 'Number_of_Hospital_Beds',
 'n_hot_rooms': 'Number_of_Hotel_Rooms',
 'waterbody': 'Fresh_Water_Resource',
 'rainfall': 'Average_Rainfall',
 'bus_ter': 'Bus_Terminal',
 'parks': 'parks'}

# %%
# Perform the renaming operation
df_house_price = df_house_price.rename(columns=d1)

# %%
# Do the authentic check
df_house_price.columns
# Out:
# Index(['Price', 'Crime_Rate', 'Residential_Area', 'Air_Quality',
#        'Room_Numbers', 'Age_of_the_House', 'dist1', 'dist2', 'dist3', 'dist4',
#        'Number_of_Teachers', 'Proportion_of_Poor_Population', 'Airport',
#        'Number_of_Hospital_Beds', 'Number_of_Hotel_Rooms',
#        'Fresh_Water_Resource', 'Average_Rainfall', 'Bus_Terminal', 'parks'],
#       dtype='object')

# %% [markdown]
# #### Null Value Handling

# %%
# Find the number of missing records in each column
df_house_price.isnull().sum()
# Out:
# Price                              0
# Crime_Rate                         0
# Residential_Area                   0
# Air_Quality                        0
# Room_Numbers                       0
# Age_of_the_House                   0
# dist1                              0
# dist2                              0
# dist3                              0
# dist4                              0
# Number_of_Teachers                 0
# Proportion_of_Poor_Population      0
# Airport                            0
# Number_of_Hospital_Beds            8
# Number_of_Hotel_Rooms              0
# Fresh_Water_Resource             155
# Average_Rainfall                   0
# Bus_Terminal                       0
# parks                              0
# dtype: int64

# %% [raw]
# percentage:  (Number of occurences/ Total number of events) * 100

# %%
# Find the percentage of missing records
df_house_price.isnull().sum()/ len(df_house_price) * 100
# Out:
# Price                             0.000000
# Crime_Rate                        0.000000
# Residential_Area                  0.000000
# Air_Quality                       0.000000
# Room_Numbers                      0.000000
# Age_of_the_House                  0.000000
# dist1                             0.000000
# dist2                             0.000000
# dist3                             0.000000
# dist4                             0.000000
# Number_of_Teachers                0.000000
# Proportion_of_Poor_Population     0.000000
# Airport                           0.000000
# Number_of_Hospital_Beds           1.581028
# Number_of_Hotel_Rooms             0.000000
# Fresh_Water_Resource             30.632411
# Average_Rainfall                  0.000000
# Bus_Terminal                      0.000000
# parks                             0.000000
# dtype: float64

# %%
# Fresh_Water_Reesource column contain highest number of missing records 
# Find the nature of the column(Is that column categorical and numerical?)
df_house_price.Fresh_Water_Resource.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 506 entries, 0 to 505
# Series name: Fresh_Water_Resource
# Non-Null Count  Dtype
# --------------  -----
# 351 non-null    object
# dtypes: object(1)
# memory usage: 4.1+ KB

# %%
# It is categorical column, let replase the nll value with mode of the coloum 
df_house_price.Fresh_Water_Resource.mode()
# Out:
# 0    River
# Name: Fresh_Water_Resource, dtype: object

# %%
#Replace the null record with the 'river'
df_house_price.Fresh_Water_Resource=df_house_price.Fresh_Water_Resource.fillna('river')

# %%
# Do the Outhentic check
df_house_price.isnull().sum()
# Out:
# Price                            0
# Crime_Rate                       0
# Residential_Area                 0
# Air_Quality                      0
# Room_Numbers                     0
# Age_of_the_House                 0
# dist1                            0
# dist2                            0
# dist3                            0
# dist4                            0
# Number_of_Teachers               0
# Proportion_of_Poor_Population    0
# Airport                          0
# Number_of_Hospital_Beds          8
# Number_of_Hotel_Rooms            0
# Fresh_Water_Resource             0
# Average_Rainfall                 0
# Bus_Terminal                     0
# parks                            0
# dtype: int64

# %%
len(df_house_price)
# Out:
# 506

# %%
# We have less than 10% data missing from Number_of_Hospital_Beds column, let's remove those observations
df_house_price.dropna(inplace=True)

# %%
# Do the authentic check
len(df_house_price)
# Out:
# 498

# %% [markdown]
# ## EDA (Exploratory Data Analysis)

# %% [markdown]
# ### Univariate Analysis

# %%
df_house_price.head()
# Out:
#    Price  Crime_Rate  Residential_Area  Air_Quality  Room_Numbers  \
# 0   24.0     0.00632             32.31        0.538         6.575
# 1   21.6     0.02731             37.07        0.469         6.421
# 2   34.7     0.02729             37.07        0.469         7.185
# 3   33.4     0.03237             32.18        0.458         6.998
# 4   36.2     0.06905             32.18        0.458         7.147
#
#    Age_of_the_House  dist1  dist2  dist3  dist4  Number_of_Teachers  \
# 0              65.2   4.35   3.81   4.18   4.01                24.7
# 1              78.9   4.99   4.70   5.12   5.06                22.2
# 2              61.1   5.03   4.86   5.01   4.97                22.2
# 3              45.8   6.21   5.93   6.16   5.96                21.3
# 4              54.2   6.16   5.86   6.37   5.86                21.3
#
#    Proportion_of_Poor_Population Airport  Number_of_Hospital_Beds  \
# 0                           4.98     YES                    5.480
# ...

# %%
# Segregate the data based on the data type
# Categorical data
df_cat = df_house_price.select_dtypes(include='object')

# Numerical data
df_num = df_house_price.select_dtypes(include='number')

# %%
# Categorical data
df_cat.head()
# Out:
#   Airport Fresh_Water_Resource Bus_Terminal
# 0     YES                River          YES
# 1      NO                 Lake          YES
# 2      NO                river          YES
# 3     YES                 Lake          YES
# 4      NO                 Lake          YES

# %%
# Numerical data
df_num.head()
# Out:
#    Price  Crime_Rate  Residential_Area  Air_Quality  Room_Numbers  \
# 0   24.0     0.00632             32.31        0.538         6.575
# 1   21.6     0.02731             37.07        0.469         6.421
# 2   34.7     0.02729             37.07        0.469         7.185
# 3   33.4     0.03237             32.18        0.458         6.998
# 4   36.2     0.06905             32.18        0.458         7.147
#
#    Age_of_the_House  dist1  dist2  dist3  dist4  Number_of_Teachers  \
# 0              65.2   4.35   3.81   4.18   4.01                24.7
# 1              78.9   4.99   4.70   5.12   5.06                22.2
# 2              61.1   5.03   4.86   5.01   4.97                22.2
# 3              45.8   6.21   5.93   6.16   5.96                21.3
# 4              54.2   6.16   5.86   6.37   5.86                21.3
#
#    Proportion_of_Poor_Population  Number_of_Hospital_Beds  \
# 0                           4.98                    5.480
# ...

# %% [markdown]
# ### Univariate analysis on numerical data

# %%
# Show the columns in the numerical data
df_num.columns
# Out:
# Index(['Price', 'Crime_Rate', 'Residential_Area', 'Air_Quality',
#        'Room_Numbers', 'Age_of_the_House', 'dist1', 'dist2', 'dist3', 'dist4',
#        'Number_of_Teachers', 'Proportion_of_Poor_Population',
#        'Number_of_Hospital_Beds', 'Number_of_Hotel_Rooms', 'Average_Rainfall',
#        'parks'],
#       dtype='object')

# %% [markdown]
# ### Interpretation
# - Average price is 22.528854, Minimum price is 5, Maximum price is 50
# - Average  crime_rate is 3.613524, Minimum crime_rate is 0.006320,Maximum crime_rate is 88.976200
# - Average resid_area is 41.136779, Minimum resid_area is 30.46, Maximum resid_area is 57.74
# - Average air_qual is 0.554695, Minimum air_qual is 0.3850, Maximum air_qual is 0.871
# - Average room_num is 6.284634, Minimum room_num is 3.5610, Maximum room_num is 8.780
# - Average age is 68.574901, Minimum age is 2.9, Maximum age is
# - Average dstance 1 is 3.628775, Minimum distance 1 is 1.130000 ,Maximum distance is 12.320000
# - Average distance 2 is 3.628775, Minimum distance 2 is 0.920000, Maximum distance is 11.930000
# - Average distance 3 is 3.960672,Minimum distance 3 is 1.150000,Maximum distance 3 is 12.320000
# - Average distance 4 is 3.618972 ,Minimum distance 4 is 0.730000,Maximum distance 4 is 11.940000
# - Average teachers is 21.544466,Minimum teachers is 18.000000, Maximum teachers is 27.400000
# - Average poor_prop is 12.653063 ,Minimum poor_prop is 1.730000, Maximum poor_prop is 37.970000
# - Average n_hos_beds is 7.899767, Minimum n_hos_beds is 5.268000 , Maximum n_hos_beds is 37.970000
# - Average n_hot_rooms is 13.041605 , Minimum n_hot_rooms is 10.057600,Maximum n_hot_rooms is 101.120000
# - Average rainfall is 39.181818,Minimum rainfall is 3.000000 ,Maximum rainfall is 60.000000
# - Average Parks is 0.054454, minimum parks is 0.033292, Maximum parks is 0.086711

# %% [markdown]
# ### Univariate Analysis on Categorical Data

# %%
# show the data in categoical data fram 
df_cat.head()
# Out:
#   Airport Fresh_Water_Resource Bus_Terminal
# 0     YES                River          YES
# 1      NO                 Lake          YES
# 2      NO                river          YES
# 3     YES                 Lake          YES
# 4      NO                 Lake          YES

# %%
df_cat.columns
# Out:
# Index(['Airport', 'Fresh_Water_Resource', 'Bus_Terminal'], dtype='object')

# %% [markdown]
# ### Airport

# %%
#Show the count of each category present in the airport
df_cat.Airport.value_counts()
# Out:
# Airport
# YES    273
# NO     225
# Name: count, dtype: int64

# %%
# Do the visulization of that count
df_cat.Airport.value_counts().plot(kind='bar',color='purple')
plt.xticks(rotation= 0)
plt.title('count of Airport')
plt.grid()
plt.ylabel('count')
plt.show()

# %% [markdown]
# ### Interpretation
# - we have 273 places where airpot is present.
# - we have 225 places where airport is not present.

# %%
df_cat.columns
# Out:
# Index(['Airport', 'Fresh_Water_Resource', 'Bus_Terminal'], dtype='object')

# %% [markdown]
# ### Fresh_Water_Resource

# %%
# show the count of Fresh_Water_Resource avallable
df_cat.Fresh_Water_Resource.value_counts()
# Out:
# Fresh_Water_Resource
# River             178
# river             155
# Lake               94
# Lake and River     71
# Name: count, dtype: int64

# %%
# Do the visualization of the count
df_cat.Fresh_Water_Resource.value_counts().plot(kind='bar')
plt.xticks(rotation= 0)
plt.title('count of Fresh_Water_Resource')
plt.grid()
plt.ylabel('count')
plt.show()

# %% [markdown]
# ### Interpritation
#
# - we have 178 River where present is fresh_water_resource
# - we have 94 Lave where present is fresh_water_resource
# - we have 71 Lake where and River present is fresh_water_resource

# %%
df_cat.columns
# Out:
# Index(['Airport', 'Fresh_Water_Resource', 'Bus_Terminal'], dtype='object')

# %% [markdown]
# ### Bus_Terminal

# %%
# show the count of Bus_Terminal avallable
df_cat.Bus_Terminal.value_counts()
# Out:
# Bus_Terminal
# YES    498
# Name: count, dtype: int64

# %%
# Do the visualization of the count
df_cat.Bus_Terminal.value_counts().plot(kind='bar')
plt.xticks(rotation= 0)
plt.title('count of Bus_Terminal')
plt.grid()
plt.ylabel('count')
plt.show()

# %% [markdown]
# ### Interpritation
#
# - we have 343 bus_terminal available

# %%
df_cat.columns
# Out:
# Index(['Airport', 'Fresh_Water_Resource', 'Bus_Terminal'], dtype='object')

# %%
# we have only one category present. So we need to delete that column.
df_cat=df_cat.drop('Bus_Terminal',axis=1)

# %%
# Delete it from main Data Frame
df_house_price=df_house_price.drop('Bus_Terminal',axis=1)

# %%
# Do the authentic check
df_cat.columns
# Out:
# Index(['Airport', 'Fresh_Water_Resource'], dtype='object')

# %%
# do the authentic check main data frame
df_house_price.columns
# Out:
# Index(['Price', 'Crime_Rate', 'Residential_Area', 'Air_Quality',
#        'Room_Numbers', 'Age_of_the_House', 'dist1', 'dist2', 'dist3', 'dist4',
#        'Number_of_Teachers', 'Proportion_of_Poor_Population', 'Airport',
#        'Number_of_Hospital_Beds', 'Number_of_Hotel_Rooms',
#        'Fresh_Water_Resource', 'Average_Rainfall', 'parks'],
#       dtype='object')

# %% [markdown]
# ### Bivariate Analysis

# %%
# show the first 5 observation of the data.
df_num.head()
# Out:
#    Price  Crime_Rate  Residential_Area  Air_Quality  Room_Numbers  \
# 0   24.0     0.00632             32.31        0.538         6.575
# 1   21.6     0.02731             37.07        0.469         6.421
# 2   34.7     0.02729             37.07        0.469         7.185
# 3   33.4     0.03237             32.18        0.458         6.998
# 4   36.2     0.06905             32.18        0.458         7.147
#
#    Age_of_the_House  dist1  dist2  dist3  dist4  Number_of_Teachers  \
# 0              65.2   4.35   3.81   4.18   4.01                24.7
# 1              78.9   4.99   4.70   5.12   5.06                22.2
# 2              61.1   5.03   4.86   5.01   4.97                22.2
# 3              45.8   6.21   5.93   6.16   5.96                21.3
# 4              54.2   6.16   5.86   6.37   5.86                21.3
#
#    Proportion_of_Poor_Population  Number_of_Hospital_Beds  \
# 0                           4.98                    5.480
# ...

# %%
# to find the pairs in Bivariate Analysis, we have to use following step.
# Step 1: Find the correlation
df_num.corr()
# Out:
#                                   Price  Crime_Rate  Residential_Area  \
# Price                          1.000000   -0.384572         -0.482223
# Crime_Rate                    -0.384572    1.000000          0.403015
# Residential_Area              -0.482223    0.403015          1.000000
# Air_Quality                   -0.430731    0.419007          0.765253
# Room_Numbers                   0.699058   -0.217803         -0.392985
# Age_of_the_House              -0.377020    0.350458          0.646088
# dist1                          0.250290   -0.378596         -0.708870
# dist2                          0.247989   -0.378102         -0.709945
# dist3                          0.245614   -0.378810         -0.709434
# dist4                          0.247557   -0.375658         -0.707921
# Number_of_Teachers             0.503035   -0.286959         -0.377254
# Proportion_of_Poor_Population -0.739174    0.454735          0.604767
# ...

# %% [raw]
# # pairs for Bivariate Analysis
# # (Residential_Area,parks)
# # (Air_Quality,Parks)
# # (dist1,parks)
# # (dist2,parks)
# # (dist3,parks)
# # (dist4,parks)
# # (Price,Proportion_of_Poor_Population)
# # (Residential_Area,dist4)
# # (Air_Quality,dist4)
# # (Age_of_the_House,dist4)
# # (dist1,dist4)
# # (dist2,dist4)
# # (dist3,dist4)
# # (Residential_Area,dist3)
# # (Air_Quality,dist3)
# # (Age_of_the_House,dist3)
# # (dist1,dist3)
# # (dist2,dist3)
# # (Residential_Area,dist2)
# # (Air_Quality,dist2)
# # (Age_of_the_House,dist2)
# # (dist1,dist2)
# # (Residential_Area,dist1)
# # (Air_Quality,dist1)
# # (Age_of_the_House,dist1)

# %% [markdown]
# ### (Residential_Area,parks)

# %%
sns.scatterplot(x='Residential_Area',y='parks',data=df_num,color='red')
plt.title('scatter plot between Residential_Area and parks')
plt.show()

# %% [markdown]
# ### Interpretation
# - It Not showe correlation

# %% [markdown]
# ### (Air_Quality,Parks)

# %%
sns.scatterplot(x='Air_Quality',y='parks',data=df_num,color='red')
plt.title('scatter plot between Air_Quality and parks')
plt.show()

# %% [markdown]
# ### Interpretation
# - It shows positively correlated
# - When ther is increses park and Air_Quality increase

# %% [markdown]
# ### dist1,parks

# %%
sns.scatterplot(x='dist1', y='parks',data=df_num, color='purple')
plt.title('scatter plot between dist1 and parks')
plt.show()

# %% [markdown]
# ### Interpretation
# - It is easy to see that there is a negative correlation
# - It means when parks increases dist1 decreases

# %% [markdown]
# ### dist2,parks

# %%
sns.scatterplot(x='dist2', y='parks',data=df_num, color='purple')
plt.title('scatter plot between dist1 and parks')
plt.show()

# %% [markdown]
# ### Interpretation
# - It is easy to see that there is a negative correlation
# - It means when parks increases dist1 decreases

# %% [markdown]
# ### dist3,parks

# %%
sns.scatterplot(x='dist3', y='parks',data=df_num, color='purple')
plt.title('scatter plot between dist3 and parks')
plt.show()

# %% [markdown]
# ### Interpretation
# - It is easy to see that there is a negative correlation
# - It means when parks increases dist3 decreases

# %% [markdown]
# ### dist4,parks

# %%
sns.scatterplot(x='dist4', y='parks',data=df_num, color='purple')
plt.title('scatter plot between dist4 and parks')
plt.show()

# %% [markdown]
# ### Interpretation
# - It is easy to see that there is a negative correlation
# - It means when parks increases dist4 decreases

# %% [markdown]
# ### Price,Proportion_of_Poor_Population

# %%
sns.scatterplot(x='Price', y='Proportion_of_Poor_Population',data=df_num, color='purple')
plt.title('scatter plot between Price and Proportion_of_Poor_Population')
plt.show()

# %% [markdown]
# ### Interpretation
# - It shows positively correlated
# - When Proportion_of_Poor_Population increased price increases

# %% [markdown]
# ### Residential_Area,dist4

# %%
sns.scatterplot(x='Residential_Area', y='dist4',data=df_num, color='purple')
plt.title('scatter plot between Residential_Area and dist4')
plt.show()

# %% [markdown]
# ### Interpretation
# - It is directly showing that negatively correlated
# - When distance4 is increased Residential_Area Decreases

# %% [markdown]
# ### Air_Quality,dist4

# %%
sns.scatterplot(x='Air_Quality', y='dist4',data=df_num, color='purple')
plt.title('scatter plot between Air_Quality and dist4')
plt.show()

# %% [markdown]
# ### Interpretation
# - It is directly showing that negatively correlated
# - When distance4 is increased Air_Qulaity Decreases

# %% [markdown]
# ### Age_of_the_House,dist4

# %%
sns.scatterplot(x='Age_of_the_House', y='dist4',data=df_num, color='purple')
plt.title('scatter plot between Age_of_the_House and dist4')
plt.show()

# %% [markdown]
# ### Interpretation
# - It is easy to see that there is a Positive correlation
# - It means when dis4 increases Age of the House increases

# %% [markdown]
# ### dist1,dist4

# %%
sns.scatterplot(x='dist1', y='dist4',data=df_num, color='purple')
plt.title('scatter plot between dist1 and dist4')
plt.show()

# %% [markdown]
# ### Interpretation
# - It is easy to see that there is a Positive correlation
# - It means when dis1 increases dist4 increases

# %% [markdown]
# ### dist2,dist4

# %%
sns.scatterplot(x='dist2', y='dist4',data=df_num, color='purple')
plt.title('scatter plot between dist2 and dist4')
plt.show()

# %% [markdown]
# ### Interpretation
# - It is easy to see that there is a Positive correlation
# - It means when dis4 increases dist2 increases

# %% [markdown]
# ### dist3,dist4

# %%
sns.scatterplot(x='dist3', y='dist4',data=df_num, color='purple')
plt.title('scatter plot between dist3 and dist4')
plt.show()

# %% [markdown]
# ### Interpretation
# - It is easy to see that there is a Positive correlation
# - It means when dis4 increases dis3 increases

# %% [markdown]
# ### Residential_Area,dist3

# %%
sns.scatterplot(x='Residential_Area', y='dist3',data=df_num, color='purple')
plt.title('scatter plot between Residential_Area and dist3')
plt.show()

# %% [markdown]
# ### Interpretaion
# - It is easy to see that there is a negative correlation
# - it means when distance3 increses residential area decreases

# %% [markdown]
# ### Air_Quality,dist3

# %%
sns.scatterplot(x='Air_Quality', y='dist3',data=df_num, color='purple')
plt.title('scatter plot between Air_Quality and dist3')
plt.show()

# %% [markdown]
# ### Interpretaion
#
# - It is easy to see that there is a negative correlation
# - it means when distance 3 increses air_Quality decreases

# %% [markdown]
# ### Age_of_the_House,dist3

# %%
sns.scatterplot(x='Age_of_the_House', y='dist3',data=df_num, color='purple')
plt.title('scatter plot between Age_of_the_House and dist3')
plt.show()

# %% [markdown]
# ### Interpretation
# - It shows positively correlated
# - When there is increase in age the distance reduces

# %% [markdown]
# ### dist1,dist3

# %%
sns.scatterplot(x='dist1', y='dist3',data=df_num, color='purple')
plt.title('scatter plot between dist1 and dist3')
plt.show()

# %% [markdown]
# ### Interpretation
# - It is easy to see that there is a Positive correlation
# - It means when dis1 increases dis3 increases

# %% [markdown]
# ### dist2,dist3

# %%
sns.scatterplot(x='dist2', y='dist3',data=df_num, color='purple')
plt.title('scatter plot between dist2 and dist3')
plt.show()

# %% [markdown]
# ### Interpretation
# - It is easy to see that there is a Positive correlation
# - It means when dis1 increases dis3 increases

# %% [markdown]
# ### Residential_Area,dist2

# %%
sns.scatterplot(x='Residential_Area', y='dist2',data=df_num, color='purple')
plt.title('scatter plot between Residential_Area and dist2')
plt.show()

# %% [markdown]
# ### Interpretaion
#
# - It is easy to see that there is a negative correlation
# - it means when distance2 increses residential area decreases

# %% [markdown]
# ### Air_Quality,dist2

# %%
sns.scatterplot(x='Air_Quality', y='dist2',data=df_num, color='purple')
plt.title('scatter plot between Air_Quality and dist2')
plt.show()

# %% [markdown]
# ### Interpretaion
# - It is easy to see that there is a negative correlation
# - it means when distance2 increses Air_Quality decreases

# %% [markdown]
# ### Age_of_the_House,dist2

# %%
sns.scatterplot(x='Age_of_the_House', y='dist2',data=df_num, color='purple')
plt.title('scatter plot between Age_of_the_House and dist2')
plt.show()

# %% [markdown]
# ### Interpretation
# - It shows positively correlated
# - When there is increase in age the distance reduces

# %% [markdown]
# ### dist1,dist2

# %%
sns.scatterplot(x='dist1', y='dist2',data=df_num, color='purple')
plt.title('scatter plot between dist1 and dist2')
plt.show()

# %% [markdown]
# ### Interpretation
# - It is easy to see that there is a Positive correlation
# - It means when dis1 increases dis3 increases

# %% [markdown]
# ### Residential_Area,dist1

# %%
sns.scatterplot(x='Residential_Area', y='dist1',data=df_num, color='purple')
plt.title('scatter plot between Residential_Area and dist1')
plt.show()

# %% [markdown]
# ### Interpretaion
# - It is easy to see that there is a negative correlation
# - it means when distance employment hub increses residential area decreases

# %% [markdown]
# ### Air_Quality,dist1

# %%
sns.scatterplot(x='Air_Quality', y='dist1',data=df_num, color='purple')
plt.title('scatter plot between Air_Quality and dist1')
plt.show()

# %% [markdown]
# ### Interpretaion
# - It is directly showing that negatively correlated.
# - When distance is increased  air quality index automatically increases.

# %% [markdown]
# ### Age_of_the_House,dist1

# %%
sns.scatterplot(x='Age_of_the_House', y='dist1',data=df_num, color='purple')
plt.title('scatter plot between Age_of_the_House and dist1')
plt.show()

# %% [markdown]
# ### Interpretaion
#
# - It shows positively correlated
# - When there is increase in age the distance reduces

# %%
# Find the pairs having strong positive or negative relation 
# Air_Quality,Parks,dist4,dist1,dist2

# %%
df_cat.head()
# Out:
#   Airport Fresh_Water_Resource
# 0     YES                River
# 1      NO                 Lake
# 2      NO                river
# 3     YES                 Lake
# 4      NO                 Lake

# %%
# pairs for 1 categorical and 1 Numerical column 
# Airport-Air_Quality
# Airport - Parks
# Fresh_Water_Resource-Air_Quality
# Fresh_Water_Resource-Parks
# Airport-dist4
# Fresh_Water_Resource-dist4
# Airport-dist1
# Fresh_Water_Resource-dist1
# Airport-dist2
# Fresh_Water_Resource-dist2

# %% [markdown]
# ### Airport-Air_Quality

# %%
# visualize the graph
sns.barplot(x='Airport',y='Air_Quality', data=df_house_price,color='purple')
plt.title('Airport vs Air_Quality')
plt.grid()
plt.show()

# %% [markdown]
# **Interpritation**
#
# - This data is balanced dat. There is no such relation Between airport and Air_Quality

# %% [markdown]
# ### Airport - Parks

# %%
# visualize the graph
sns.barplot(x='Airport',y='parks', data=df_house_price,color='purple')
plt.title('Airport vs parks')
plt.grid()
plt.show()

# %% [markdown]
# **Interpritation**
# - This data is balanced dat. There is no such relation Between Airport and parks

# %% [markdown]
# ### Fresh_Water_Resource-Air_Quality

# %%
# visualize the graph
sns.barplot(x='Fresh_Water_Resource',y='Air_Quality', data=df_house_price,color='purple')
plt.title('Fresh_Water_Resource vs Air_Quality')
plt.grid()
plt.show()

# %% [markdown]
# **Interpritation**
# - This data is balance data.There is no such relation between Fresh_Water_Resource and Air_Quality

# %% [markdown]
# ### Fresh_Water_Resource-Parks

# %%
# visualize the graph
sns.barplot(x='Fresh_Water_Resource',y='parks', data=df_house_price,color='purple')
plt.title('Fresh_Water_Resource vs parks')
plt.grid()
plt.show()

# %% [markdown]
# **Interpritation**
# - This data is balance data.There is no such relation between Fresh_Water_Resource and Air_Quality

# %% [markdown]
# ### Airport-dist4

# %%
# visualize the graph
sns.barplot(x='Airport',y='dist4', data=df_house_price,color='purple')
plt.title('Airport vs dist4')
plt.grid()
plt.show()

# %% [markdown]
# **Interpritation**
# - This data is balance data . There is no such relation between Airport and Distance4

# %% [markdown]
# ### Fresh_Water_Resource-dist4

# %%
# visualize the graph
sns.barplot(x='Fresh_Water_Resource',y='dist4', data=df_house_price,color='purple')
plt.title('Fresh_Water_Resource vs dist4')
plt.grid()
plt.show()

# %% [markdown]
# **Interpritation**
#
# - This data is balance data . There is no such relation between Fresh_Water_Resource and Distance4

# %% [markdown]
# ### Airport-dist1

# %%
# visualize the graph
sns.barplot(x='Airport',y='dist1', data=df_house_price,color='purple')
plt.title('Airport vs dist1')
plt.grid()
plt.show()

# %% [markdown]
# **Interpritation**
# - This data is balance data . There is no such relation between Fresh_Water_Resource and Distance_From_Industries

# %% [markdown]
# ### Fresh_Water_Resource-dist1

# %%
# visualize the graph
sns.barplot(x='Fresh_Water_Resource',y='dist1', data=df_house_price,color='purple')
plt.title('Fresh_Water_Resource vs dist1')
plt.grid()
plt.show()

# %% [markdown]
# **Interpritation**
#
# - This data is balance data . There is no such relation between Fresh_Water_Resource and Distance.

# %% [markdown]
# ###  Airport-dist2

# %%
# visualize the graph
sns.barplot(x='Airport',y='dist2', data=df_house_price,color='purple')
plt.title('Airport vs dist2')
plt.grid()
plt.show()

# %% [markdown]
# **Interpritation**
#
# This data is balance data . There is no such relation between Airport and Distance2.

# %% [markdown]
# ### Fresh_Water_Resource-dist2

# %%
# visualize the graph
sns.barplot(x='Fresh_Water_Resource',y='dist2', data=df_house_price,color='purple')
plt.title('Fresh_Water_Resource vs dist2')
plt.grid()
plt.show()

# %% [markdown]
# **Interpritation**
#
# - This data is balance data . There is no such relation between Fresh_Water_Resource and Distance2

# %% [markdown]
# ### Multivariate Analysis

# %%
# Categorical Columns: Airport, Fresh_water_resorses
# Numerical Columns: Air_Quality,Parks,dist4,dist1,dist2

# %%
# map the pair
# Airport, Fresh_water_resorses,Air_Quality
# Airport, Fresh_water_resorses,Parks
# Airport, Fresh_water_resorses,dist4
# Airport, Fresh_water_resorses,dist1
# Airport, Fresh_water_resorses,dist2

# %% [markdown]
# ### Airport, Fresh_water_resorses,Air_Quality

# %%
# Draw the syntax 
pd.crosstab(index=df_house_price.Airport,columns=df_house_price.Fresh_Water_Resource, values=df_house_price.Air_Quality,
            aggfunc='min')
# Out:
# Fresh_Water_Resource  Lake  Lake and River  River  river
# Airport
# NO                     0.4           0.398  0.392  0.392
# YES                    0.4           0.400  0.400  0.385

# %% [markdown]
# **Interpretation**
# - When we dont have the Airport is lake the minimum Air_Quality is 0.4
# - When we have the Airport is lake the Minimum AirQuality is 0.4
# - When we dont have the Airport is Lake and River the minimum Air_quality is 0.398
# - When we have the Airport is Lake and River the minimum Air_Qality is 0.400
# - When we dont have the Airport is River the minimum Air_Quality is 0.392
# - When we have the Airport is River the minimum Air_Quality is 0.400

# %%
pd.crosstab(index=df_house_price.Airport,columns=df_house_price.Fresh_Water_Resource, values=df_house_price.Air_Quality,
            aggfunc='max')
# Out:
# Fresh_Water_Resource   Lake  Lake and River  River  river
# Airport
# NO                    0.871           0.871  0.871  0.871
# YES                   0.871           0.770  0.871  0.871

# %% [markdown]
# ### Interpretation
# - When we dont have the Airport is lake the maximum Air_Quality is 0.871
# - When we have the Airport is lake the maximum AirQuality is 0.871
# - When we dont have the Airport is Lake and River the maximum Air_quality is 0.871
# - When we have the Airport is Lake and River the maximum Air_Qality is 0.770
# - When we dont have the Airport is River the maximum Air_Quality is 0.871
# - When we have the Airport is River the maximum Air_Quality is 0.871

# %%
pd.crosstab(index=df_house_price.Airport,columns=df_house_price.Fresh_Water_Resource, values=df_house_price.Air_Quality,
            aggfunc='mean')
# Out:
# Fresh_Water_Resource      Lake  Lake and River     River     river
# Airport
# NO                    0.559790        0.574842  0.544203  0.580377
# YES                   0.527235        0.540033  0.550617  0.555614

# %% [markdown]
# ### Interpritation
# - When we dont have the Airport is lake the Average Air_Quality is 0.559790
# - When we have the Airport is lake the maximum AirQuality is 0.527235
# - When we dont have the Airport is Lake and River the maximum Air_quality is 0.574842
# - When we have the Airport is Lake and River the maximum Air_Qality is 0.540033
# - When we dont have the Airport is River the maximum Air_Quality is 0.544203
# - When we have the Airport is River the maximum Air_Quality is 0.550617
